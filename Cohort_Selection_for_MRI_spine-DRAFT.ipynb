# %% [markdown]
# # MIDRC Cohort Selection and Image Downloading For MRI Spine Imaging Studies
# ---
# By Heather Whitney, PhD (Department of Radiology at the University of Chicago, hwhitney at uchicago.edu)
#
# Based on code by Chris Meyer, PhD (Center for Translational Data Science at the University of Chicago)
#
#
# May 2023
#
# ---
# This Jupyter notebook tutorial demonstrates how to use the MIDRC data commons' APIs to access imaging study data  and how to access those image files. It was developed to facilitate the Data Science MRI bootcamp held at the 2023 Annual Meeting of the American Association of Physicists in Medicine.
#
# # Python packages:

# %%
# The packages below may be necessary for users to install according to the imports necessary in the subsequent cells.

# !pip install --upgrade pandas
# !pip install --upgrade --ignore-installed PyYAML
# !pip install --upgrade pip
# !pip install gen3
# !pip install --upgrade gen3 --user --upgrade
#!pip install cdiserrors
#!pip install --upgrade pydicom
# !pip install pydicom
#!pip install pylibjpeg
#!pip install -U python-gdcm
# Out:
# Requirement already satisfied: pandas in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting PyYAML
#   Using cached PyYAML-6.0-cp38-cp38-macosx_10_9_x86_64.whl (192 kB)
# Installing collected packages: PyYAML
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.41 requires pathlib, which is not installed.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# dictionaryutils 3.0.0 requires PyYAML~=5.1, but you have pyyaml 6.0 which is incompatible.
# gdcdictionary 1.2.0 requires PyYAML~=5.1, but you have pyyaml 6.0 which is incompatible.
# pypfb 0.5.0 requires PyYAML<6.0.0,>=5.3.1, but you have pyyaml 6.0 which is incompatible.
# Successfully installed PyYAML-5.4.1
# Requirement already satisfied: pip in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (23.1.2)
# Collecting pip
#   Downloading pip-23.2-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 11.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.2
#     Uninstalling pip-23.1.2:
#       Successfully uninstalled pip-23.1.2
# Successfully installed pip-23.2
# Requirement already satisfied: gen3 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (4.9.4)
# Requirement already satisfied: aiofiles<0.9.0,>=0.8.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (0.8.0)
# Requirement already satisfied: aiohttp in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (3.8.4)
# Requirement already satisfied: backoff in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (1.11.1)
# Requirement already satisfied: click in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (7.1.2)
# Requirement already satisfied: dataclasses-json in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (0.5.7)
# Requirement already satisfied: drsclient<1.0.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (0.1.6)
# Requirement already satisfied: fastavro<2.0.0,>=1.4.7 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (1.7.2)
# Requirement already satisfied: humanfriendly in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (10.0)
# Requirement already satisfied: indexclient>=1.6.2 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (2.1.1)
# Requirement already satisfied: jsonschema in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (2.5.1)
# Requirement already satisfied: pandas in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (2.0.3)
# Requirement already satisfied: pypfb<1.0.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (0.5.0)
# Requirement already satisfied: python-dateutil in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (2.8.2)
# Requirement already satisfied: requests in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (2.28.1)
# Requirement already satisfied: tqdm>=4.61.2 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (4.64.1)
# Requirement already satisfied: asyncio<4.0.0,>=3.4.3 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from drsclient<1.0.0->gen3) (3.4.3)
# Requirement already satisfied: httpx<0.16,>=0.15 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from drsclient<1.0.0->gen3) (0.15.5)
# Requirement already satisfied: PyYAML<6.0.0,>=5.3.1 in /Users/heatherwhitney/.local/lib/python3.8/site-packages (from pypfb<1.0.0->gen3) (5.4.1)
# Requirement already satisfied: dictionaryutils<=3.0.2 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pypfb<1.0.0->gen3) (3.0.0)
# Requirement already satisfied: gdcdictionary<2.0.0,>=1.2.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pypfb<1.0.0->gen3) (1.2.0)
# Requirement already satisfied: python-json-logger<0.2.0,>=0.1.11 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pypfb<1.0.0->gen3) (0.1.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from requests->gen3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from requests->gen3) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from requests->gen3) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from requests->gen3) (2022.12.7)
# Requirement already satisfied: attrs>=17.3.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gen3) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gen3) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gen3) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gen3) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gen3) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gen3) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from dataclasses-json->gen3) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from dataclasses-json->gen3) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from dataclasses-json->gen3) (0.8.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pandas->gen3) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pandas->gen3) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pandas->gen3) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil->gen3) (1.16.0)
# Requirement already satisfied: cdislogging~=1.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from dictionaryutils<=3.0.2->pypfb<1.0.0->gen3) (1.1.1)
# Requirement already satisfied: sniffio in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from httpx<0.16,>=0.15->drsclient<1.0.0->gen3) (1.2.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from httpx<0.16,>=0.15->drsclient<1.0.0->gen3) (1.5.0)
# Requirement already satisfied: httpcore==0.11.* in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from httpx<0.16,>=0.15->drsclient<1.0.0->gen3) (0.11.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from httpcore==0.11.*->httpx<0.16,>=0.15->drsclient<1.0.0->gen3) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json->gen3) (22.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from typing-inspect>=0.4.0->dataclasses-json->gen3) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from typing-inspect>=0.4.0->dataclasses-json->gen3) (4.4.0)
# Requirement already satisfied: gen3 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (4.9.4)
# Requirement already satisfied: aiofiles<0.9.0,>=0.8.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (0.8.0)
# Requirement already satisfied: aiohttp in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (3.8.4)
# Requirement already satisfied: backoff in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (1.11.1)
# Requirement already satisfied: click in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (7.1.2)
# Requirement already satisfied: dataclasses-json in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (0.5.7)
# Requirement already satisfied: drsclient<1.0.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (0.1.6)
# Requirement already satisfied: fastavro<2.0.0,>=1.4.7 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (1.7.2)
# Requirement already satisfied: humanfriendly in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (10.0)
# Requirement already satisfied: indexclient>=1.6.2 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (2.1.1)
# Requirement already satisfied: jsonschema in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (2.5.1)
# Requirement already satisfied: pandas in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (2.0.3)
# Requirement already satisfied: pypfb<1.0.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (0.5.0)
# Requirement already satisfied: python-dateutil in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (2.8.2)
# Requirement already satisfied: requests in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (2.28.1)
# Requirement already satisfied: tqdm>=4.61.2 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from gen3) (4.64.1)
# Requirement already satisfied: asyncio<4.0.0,>=3.4.3 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from drsclient<1.0.0->gen3) (3.4.3)
# Requirement already satisfied: httpx<0.16,>=0.15 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from drsclient<1.0.0->gen3) (0.15.5)
# Requirement already satisfied: PyYAML<6.0.0,>=5.3.1 in /Users/heatherwhitney/.local/lib/python3.8/site-packages (from pypfb<1.0.0->gen3) (5.4.1)
# Requirement already satisfied: dictionaryutils<=3.0.2 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pypfb<1.0.0->gen3) (3.0.0)
# Requirement already satisfied: gdcdictionary<2.0.0,>=1.2.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pypfb<1.0.0->gen3) (1.2.0)
# Requirement already satisfied: python-json-logger<0.2.0,>=0.1.11 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pypfb<1.0.0->gen3) (0.1.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from requests->gen3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from requests->gen3) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from requests->gen3) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from requests->gen3) (2022.12.7)
# Requirement already satisfied: attrs>=17.3.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gen3) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gen3) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gen3) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gen3) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gen3) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from aiohttp->gen3) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from dataclasses-json->gen3) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from dataclasses-json->gen3) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from dataclasses-json->gen3) (0.8.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pandas->gen3) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pandas->gen3) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from pandas->gen3) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil->gen3) (1.16.0)
# Requirement already satisfied: cdislogging~=1.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from dictionaryutils<=3.0.2->pypfb<1.0.0->gen3) (1.1.1)
# Requirement already satisfied: sniffio in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from httpx<0.16,>=0.15->drsclient<1.0.0->gen3) (1.2.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from httpx<0.16,>=0.15->drsclient<1.0.0->gen3) (1.5.0)
# Requirement already satisfied: httpcore==0.11.* in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from httpx<0.16,>=0.15->drsclient<1.0.0->gen3) (0.11.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from httpcore==0.11.*->httpx<0.16,>=0.15->drsclient<1.0.0->gen3) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json->gen3) (22.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from typing-inspect>=0.4.0->dataclasses-json->gen3) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (from typing-inspect>=0.4.0->dataclasses-json->gen3) (4.4.0)
# Requirement already satisfied: pydicom in /Users/heatherwhitney/opt/anaconda3/lib/python3.8/site-packages (2.4.1)

# %% [markdown]
# # Import Python Packages and scripts

# %%
# Import Python Packages and scripts
import pandas as pd
import sys, os, webbrowser
import gen3
import pydicom
import matplotlib.pyplot as plt

from gen3.submission import Gen3Submission
from gen3.auth import Gen3Auth
from gen3.index import Gen3Index
from gen3.query import Gen3Query

# %%
# Import some custom Python scripts from personal GitHub repo
# change these directory paths to reflect your local working directory

home_dir = "/Users/heatherwhitney" 
demo_dir = "{}/Documents/MRIbootcamp".format(home_dir)

os.chdir(demo_dir)

#os.system("wget https://raw.githubusercontent.com/cgmeyer/gen3sdk-python/master/expansion/expansion.py -O {}/expansion.py".format(demo_dir))
# %run expansion.py

# %%
# Initiate instances of the Gen3 SDK Classes using credentials file for authentication
# Set up these credentials using instructions at https://data.midrc.org/dashboard/Public/documentation/Gen3_MIDRC_GetStarted.pdf
# Change the directory path in "cred" to reflect the location where you saved your credentials file.

api = "https://data.midrc.org"
cred = "{}/Documents/MRIbootcamp/credentials.json".format(home_dir)
auth = Gen3Auth(api, refresh_file=cred) # authentication class
sub = Gen3Submission(api, auth) # submission class
query = Gen3Query(auth) # query class
exp = Gen3Expansion(api,auth,sub) # class with some custom scripts
exp.get_project_ids()
# Out:
# Getting all project_ids you have access to in the data commons.
# ['Open-A1', 'Open-A1_PETAL_REDCORAL', 'Open-R1', 'TCIA-COVID-19-AR', 'TCIA-COVID-19-NY-SBU', 'TCIA-COVID-19_CT_Images', 'TCIA-RICORD']
# ['Open-A1',
#  'Open-A1_PETAL_REDCORAL',
#  'Open-R1',
#  'TCIA-COVID-19-AR',
#  'TCIA-COVID-19-NY-SBU',
#  'TCIA-COVID-19_CT_Images',
#  'TCIA-RICORD']

# %%
# IMAGING STUDY NODE: Export all records in the imaging_study node
st = exp.get_node_tsvs(node = 'imaging_study')
print('\nrows:{}, columns:{}'.format(st.shape[0], st.shape[1]))
t = list(set(st['case_ids']))
display(len(t))
st.head(3)
# Out:
# File previously downloaded.
# node_tsvs/imaging_study_tsvs/Open-R1_imaging_study.tsv has 76905 records.
# File previously downloaded.
# node_tsvs/imaging_study_tsvs/TCIA-COVID-19-NY-SBU_imaging_study.tsv has 7363 records.
# File previously downloaded.
# node_tsvs/imaging_study_tsvs/TCIA-COVID-19_CT_Images_imaging_study.tsv has 753 records.
# File previously downloaded.
# node_tsvs/imaging_study_tsvs/TCIA-RICORD_imaging_study.tsv has 1238 records.
# File previously downloaded.
# node_tsvs/imaging_study_tsvs/TCIA-COVID-19-AR_imaging_study.tsv has 256 records.
# File previously downloaded.
# node_tsvs/imaging_study_tsvs/Open-A1_imaging_study.tsv has 57211 records.
# File previously downloaded.
# node_tsvs/imaging_study_tsvs/Open-A1_PETAL_REDCORAL_imaging_study.tsv has 3170 records.
# length of all dfs: 146896
# Master node TSV with 146896 total records written to master_imaging_study.tsv.
#
# rows:146896, columns:24
# 58685
#             type                                    id project_id  \
# 0  imaging_study  0002f8b1-7079-4510-9967-7bdffb3fa155    Open-R1
# 1  imaging_study  000555ed-a633-4495-a98d-43ada69216a2    Open-R1
# 2  imaging_study  0005b825-377f-4170-96e9-8c5d42036bac    Open-R1
#
#                                         submitter_id  age_at_imaging  \
# 0          1.2.826.0.1.3680043.10.474.302028.1411134             2.0
# 1  1.2.826.0.1.3680043.10.474.419639.104706049142...            61.0
# 2          1.2.826.0.1.3680043.10.474.302028.1251677            26.0
#
#   age_at_imaging_gt89 body_part_examined       case_ids  \
# 0                  No              CHEST  302028-003859
# 1                  No              CHEST  419639-008711
# 2                  No              CHEST  302028-002059
#
#     days_from_study_to_neg_covid_test days_from_study_to_pos_covid_test  ...  \
# 0  484,426,357,331,191,84,0,-108,-187                               NaN  ...
# 1                       -5,-9,-38,-72                               NaN  ...
# 2                       0,-17,-67,-86                               NaN  ...
#
#    loinc_method loinc_system         study_description study_location  \
# 0            XR        Chest           XR CHEST 1 VIEW            NaN
# 1            XR        Chest        XR CHEST 1 VIEW AP            NaN
# 2   XR.portable        Chest  XR CHEST PORTABLE 1 VIEW            NaN
#
#   study_modality                                          study_uid  \
# 0             CR          1.2.826.0.1.3680043.10.474.302028.1411134
# 1             CR  1.2.826.0.1.3680043.10.474.419639.104706049142...
# 2             DX          1.2.826.0.1.3680043.10.474.302028.1251677
#
#   study_year  study_year_shifted                              cases.id  \
# 0     2020.0               False  71a258a3-7566-42b7-a9ce-9b8fac63816f
# 1        NaN                True  3e8d4c3d-887d-4937-95d9-a81a5eae0792
# 2     2020.0               False  c3297960-c430-4b06-a9f5-9d833f4120cf
#
#   cases.submitter_id
# 0      302028-003859
# 1      419639-008711
# 2      302028-002059
#
# [3 rows x 24 columns]

# %%
# IMAGING STUDY NODE: retain those with MR study modality
s = st.loc[(st['study_modality']=='MR') ]
# optional for display
t = list(set(s['case_ids']))
display(len(t))
# print('\nrows:{}, columns:{}'.format(s.shape[0], s.shape[1]))
s.head(5)
display(list(s))
temp = s
# Out:
# 133
# ['type',
#  'id',
#  'project_id',
#  'submitter_id',
#  'age_at_imaging',
#  'age_at_imaging_gt89',
#  'body_part_examined',
#  'case_ids',
#  'days_from_study_to_neg_covid_test',
#  'days_from_study_to_pos_covid_test',
#  'days_to_study',
#  'loinc_code',
#  'loinc_contrast',
#  'loinc_long_common_name',
#  'loinc_method',
#  'loinc_system',
#  'study_description',
#  'study_location',
#  'study_modality',
#  'study_uid',
#  'study_year',
#  'study_year_shifted',
#  'cases.id',
#  'cases.submitter_id']

# %% [markdown]
# ## Identify MR imaging studies of the spine

# %%
ps = temp.loc[(s['study_description'] == 'MR SPINE LUMBAR WO CONTRAST')]
# option: negative cases only
#ps = temp.loc[ (temp['test_result_text']=='Negative')]
# option: all cases with any COVID test information
#ps = temp;
t = list(set(ps['case_ids']))
display(len(t))
display(ps)
# Out:
# 22
#                  type                                    id project_id  \
# 91075   imaging_study  1477a845-04ee-4367-a0a2-258250f7e6b2    Open-A1
# 92304   imaging_study  19f6ee92-ac46-4324-b85a-8d694a1779a3    Open-A1
# 92764   imaging_study  1c0791fa-37de-408d-85e6-1acf127b00ae    Open-A1
# 101517  imaging_study  42c456ee-87de-4d4c-9972-f3006d5ced82    Open-A1
# 109635  imaging_study  6704d7d5-6f11-4d70-9c7b-e96deadeba66    Open-A1
# 111051  imaging_study  6cd59ce8-572e-46f8-9048-88f3c662d80b    Open-A1
# 112670  imaging_study  7441f65e-f3ac-413a-b22e-2aed0cfa865a    Open-A1
# 112888  imaging_study  755113bf-1444-41c8-ab0b-b599959c324b    Open-A1
# 113613  imaging_study  7878e164-2c2a-4cb5-b17a-2f2aff039066    Open-A1
# 114559  imaging_study  7cb2139e-249c-4b14-bb24-bb51583e6807    Open-A1
# 115007  imaging_study  7eaebbd0-4fa5-48c8-a3ad-15a22ab1994b    Open-A1
# 120014  imaging_study  95579243-9b6a-4bdf-b802-3ca23a8eb223    Open-A1
# 121493  imaging_study  9c16f42f-0744-4155-a9ff-314bf42ec0ad    Open-A1
# 127132  imaging_study  b55f2ce1-6981-4d3a-833c-2479c4242446    Open-A1
# 127696  imaging_study  b7dae74d-78f0-4923-a9f7-8a6e0681bcb7    Open-A1
# 128813  imaging_study  bd014695-07e7-492b-865d-8f5b3b4ae072    Open-A1
# 132332  imaging_study  ccfbceb9-e918-4ba0-94c0-2a764e5afd72    Open-A1
# 133028  imaging_study  d024609e-dfdb-4e92-a76a-73fee435b04d    Open-A1
# 134046  imaging_study  d4df6e5f-9da9-45a1-a244-c60ba442b822    Open-A1
# 134664  imaging_study  d7a2cbb8-6a8a-496b-ab9f-cfb8a16d005f    Open-A1
# 141142  imaging_study  f4afc6bb-b179-4294-8500-a2313e9e0c5d    Open-A1
# 143390  imaging_study  fe81a0d8-831c-43d1-9783-0e15cbc3434a    Open-A1
#
#                                              submitter_id  age_at_imaging  \
# 91075   2.16.840.1.114274.1818.55812721724815372581189...            41.0
# 92304   2.16.840.1.114274.1818.49863489704487727621193...            32.0
# 92764   2.16.840.1.114274.1818.55816535374091571574831...            50.0
# 101517  2.16.840.1.114274.1818.49363651897124726091109...            70.0
# 109635  2.16.840.1.114274.1818.57513909915417576111032...            69.0
# 111051  2.16.840.1.114274.1818.51383238972914735621593...            45.0
# 112670  2.16.840.1.114274.1818.54290417108773167691434...            57.0
# 112888  2.16.840.1.114274.1818.49062652536657148311009...            33.0
# 113613  2.16.840.1.114274.1818.46697798819023351601590...            78.0
# 114559  2.16.840.1.114274.1818.47817901536556695159436...            58.0
# 115007  2.16.840.1.114274.1818.54757268450091018843048...            79.0
# 120014  2.16.840.1.114274.1818.57497365066328244448040...            26.0
# 121493  2.16.840.1.114274.1818.49602351233982522767782...            69.0
# 127132  2.16.840.1.114274.1818.47964712286237084019208...            62.0
# 127696  2.16.840.1.114274.1818.50140080742274240091251...            36.0
# 128813  2.16.840.1.114274.1818.51212583088991579111529...             NaN
# 132332  2.16.840.1.114274.1818.47382877056095326991775...            64.0
# 133028  2.16.840.1.114274.1818.54961952074504765995451...            60.0
# 134046  2.16.840.1.114274.1818.46232284683605922641091...            53.0
# 134664  2.16.840.1.114274.1818.54585802461395040361743...            71.0
# 141142  1.3.6.1.4.1.5962.99.1.3492129840.282517718.161...            53.0
# 143390  2.16.840.1.114274.1818.47775759738981156981256...            41.0
#
#        age_at_imaging_gt89 body_part_examined          case_ids  \
# 91075                   No                NaN  10000364-2397900
# 92304                   No                NaN  10000364-2022035
# 92764                   No                NaN  10000364-1058096
# 101517                  No                NaN  10000364-1437263
# 109635                  No                NaN  10000364-5461045
# 111051                  No                NaN  10000364-5314069
# 112670                  No                NaN  10000364-1503940
# 112888                  No                NaN  10000364-1119749
# 113613                  No                NaN   10000364-784361
# 114559                  No                NaN   10000364-950007
# 115007                  No                NaN  10000364-2414476
# 120014                  No                NaN  10000364-6521243
# 121493                  No                NaN  10000364-1116590
# 127132                  No                NaN  10000364-5644815
# 127696                  No                NaN  10000364-2008660
# 128813                 NaN                NaN  10000364-2606429
# 132332                  No                NaN  10000364-1662429
# 133028                  No                NaN   10000364-840782
# 134046                  No                NaN   10000364-143380
# 134664                  No                NaN  10000364-1436212
# 141142                 NaN                NaN  10000364-1786441
# 143390                  No                NaN  10000364-1406677
#
#        days_from_study_to_neg_covid_test days_from_study_to_pos_covid_test  \
# 91075                                178                           164,147
# 92304                                  0                                 1
# 92764                                NaN                               -13
# 101517                               NaN                                 0
# 109635                         185,182,0                                12
# 111051                                -2                               108
# 112670                               NaN                               -17
# 112888                                -2                                98
# 113613                            -2,-24                                20
# 114559                               NaN                              -120
# 115007                              -109                                59
# 120014                               NaN                                90
# 121493                            17,-28                             92,88
# 127132                               NaN                               289
# 127696                              -154                              -154
# 128813                               258                               283
# 132332                                 0                                 0
# 133028                               NaN                                -2
# 134046                            346,41                                -7
# 134664                               189                                 0
# 141142                               NaN                               278
# 143390                               NaN                                33
#
#         ...  loinc_method loinc_system            study_description  \
# 91075   ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 92304   ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 92764   ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 101517  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 109635  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 111051  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 112670  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 112888  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 113613  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 114559  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 115007  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 120014  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 121493  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 127132  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 127696  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 128813  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 132332  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 133028  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 134046  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 134664  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 141142  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 143390  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
#
#        study_location study_modality  \
# 91075             NaN             MR
# 92304             NaN             MR
# 92764             NaN             MR
# 101517            NaN             MR
# 109635            NaN             MR
# 111051            NaN             MR
# 112670            NaN             MR
# 112888            NaN             MR
# 113613            NaN             MR
# 114559            NaN             MR
# 115007            NaN             MR
# 120014            NaN             MR
# 121493            NaN             MR
# 127132            NaN             MR
# 127696            NaN             MR
# 128813            NaN             MR
# 132332            NaN             MR
# 133028            NaN             MR
# 134046            NaN             MR
# 134664            NaN             MR
# 141142            NaN             MR
# 143390            NaN             MR
#
#                                                 study_uid study_year  \
# 91075   2.16.840.1.114274.1818.55812721724815372581189...        NaN
# 92304   2.16.840.1.114274.1818.49863489704487727621193...        NaN
# 92764   2.16.840.1.114274.1818.55816535374091571574831...        NaN
# 101517  2.16.840.1.114274.1818.49363651897124726091109...        NaN
# 109635  2.16.840.1.114274.1818.57513909915417576111032...        NaN
# 111051  2.16.840.1.114274.1818.51383238972914735621593...        NaN
# 112670  2.16.840.1.114274.1818.54290417108773167691434...        NaN
# 112888  2.16.840.1.114274.1818.49062652536657148311009...        NaN
# 113613  2.16.840.1.114274.1818.46697798819023351601590...        NaN
# 114559  2.16.840.1.114274.1818.47817901536556695159436...        NaN
# 115007  2.16.840.1.114274.1818.54757268450091018843048...        NaN
# 120014  2.16.840.1.114274.1818.57497365066328244448040...        NaN
# 121493  2.16.840.1.114274.1818.49602351233982522767782...        NaN
# 127132  2.16.840.1.114274.1818.47964712286237084019208...        NaN
# 127696  2.16.840.1.114274.1818.50140080742274240091251...        NaN
# 128813  2.16.840.1.114274.1818.51212583088991579111529...        NaN
# 132332  2.16.840.1.114274.1818.47382877056095326991775...        NaN
# 133028  2.16.840.1.114274.1818.54961952074504765995451...        NaN
# 134046  2.16.840.1.114274.1818.46232284683605922641091...        NaN
# 134664  2.16.840.1.114274.1818.54585802461395040361743...        NaN
# 141142  1.3.6.1.4.1.5962.99.1.3492129840.282517718.161...        NaN
# 143390  2.16.840.1.114274.1818.47775759738981156981256...        NaN
#
#         study_year_shifted                              cases.id  \
# 91075                 True  0401646d-2682-496f-9d57-b859f4f2c8db
# 92304                 True  4d8b7497-a45f-4383-aeb0-5aee6eae1b65
# 92764                 True  56592e71-b345-4e2c-877c-78213e678297
# 101517                True  36614f91-9336-453c-b2f7-0b1d58465c8e
# 109635                True  0cbda608-e393-4826-853c-1a8fa15dca3a
# 111051                True  7f9efb61-c274-4a85-89f6-e6f64d62841f
# 112670                True  1c6bbe26-d778-408e-973f-2476a162421c
# 112888                True  eeb3b5a2-2fb6-44ee-88bc-768957f56fa8
# 113613                True  bc03a400-2bb4-4912-a3f5-055007bae1bc
# 114559                True  f8f9d881-f904-44a0-81f5-a65be676d646
# 115007                True  994cb5ce-a99b-4afb-87ee-099ac58a4e88
# 120014                True  05a03323-4f59-4c6d-a68e-92704c31c318
# 121493                True  1e5683db-0fc0-4991-9802-9a13265bf7e0
# 127132                True  f7c5c269-8dd0-4c5c-bfcc-bf8dda41ebce
# 127696                True  8b604837-4884-4fa5-8b54-83208cea3778
# 128813                True  785008ca-5063-4ac9-aeb2-c9d2efa97c40
# 132332                True  c4726872-3889-43c3-b2d9-dfacc6497ed5
# 133028                True  b81f0317-fdc3-494d-905e-8448cb0e28c2
# 134046                True  46c8c5d4-2d89-4528-ba69-0edf45525496
# 134664                True  91316df5-eba2-4574-a59a-4e4f2c383f9b
# 141142                 NaN  7081f132-5fea-44fe-ad8c-d526249aedca
# 143390                True  d39a5625-2b27-4e39-a0a2-c154e643347a
#
#        cases.submitter_id
# 91075    10000364-2397900
# 92304    10000364-2022035
# 92764    10000364-1058096
# 101517   10000364-1437263
# 109635   10000364-5461045
# 111051   10000364-5314069
# 112670   10000364-1503940
# 112888   10000364-1119749
# 113613    10000364-784361
# 114559    10000364-950007
# 115007   10000364-2414476
# 120014   10000364-6521243
# 121493   10000364-1116590
# 127132   10000364-5644815
# 127696   10000364-2008660
# 128813   10000364-2606429
# 132332   10000364-1662429
# 133028    10000364-840782
# 134046    10000364-143380
# 134664   10000364-1436212
# 141142   10000364-1786441
# 143390   10000364-1406677
#
# [22 rows x 24 columns]

# %%
#Saving the data frame to a csv
os.chdir(demo_dir)
filename = 'MR_records.tsv' 
ps.to_csv(filename,sep='\t',index=False)
ps.head(5)
# Out:
#                  type                                    id project_id  \
# 91075   imaging_study  1477a845-04ee-4367-a0a2-258250f7e6b2    Open-A1
# 92304   imaging_study  19f6ee92-ac46-4324-b85a-8d694a1779a3    Open-A1
# 92764   imaging_study  1c0791fa-37de-408d-85e6-1acf127b00ae    Open-A1
# 101517  imaging_study  42c456ee-87de-4d4c-9972-f3006d5ced82    Open-A1
# 109635  imaging_study  6704d7d5-6f11-4d70-9c7b-e96deadeba66    Open-A1
#
#                                              submitter_id  age_at_imaging  \
# 91075   2.16.840.1.114274.1818.55812721724815372581189...            41.0
# 92304   2.16.840.1.114274.1818.49863489704487727621193...            32.0
# 92764   2.16.840.1.114274.1818.55816535374091571574831...            50.0
# 101517  2.16.840.1.114274.1818.49363651897124726091109...            70.0
# 109635  2.16.840.1.114274.1818.57513909915417576111032...            69.0
#
#        age_at_imaging_gt89 body_part_examined          case_ids  \
# 91075                   No                NaN  10000364-2397900
# 92304                   No                NaN  10000364-2022035
# 92764                   No                NaN  10000364-1058096
# 101517                  No                NaN  10000364-1437263
# 109635                  No                NaN  10000364-5461045
#
#        days_from_study_to_neg_covid_test days_from_study_to_pos_covid_test  \
# 91075                                178                           164,147
# 92304                                  0                                 1
# 92764                                NaN                               -13
# 101517                               NaN                                 0
# 109635                         185,182,0                                12
#
#         ...  loinc_method loinc_system            study_description  \
# 91075   ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 92304   ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 92764   ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 101517  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
# 109635  ...            MR          NaN  MR SPINE LUMBAR WO CONTRAST
#
#        study_location study_modality  \
# 91075             NaN             MR
# 92304             NaN             MR
# 92764             NaN             MR
# 101517            NaN             MR
# 109635            NaN             MR
#
#                                                 study_uid study_year  \
# 91075   2.16.840.1.114274.1818.55812721724815372581189...        NaN
# 92304   2.16.840.1.114274.1818.49863489704487727621193...        NaN
# 92764   2.16.840.1.114274.1818.55816535374091571574831...        NaN
# 101517  2.16.840.1.114274.1818.49363651897124726091109...        NaN
# 109635  2.16.840.1.114274.1818.57513909915417576111032...        NaN
#
#         study_year_shifted                              cases.id  \
# 91075                 True  0401646d-2682-496f-9d57-b859f4f2c8db
# 92304                 True  4d8b7497-a45f-4383-aeb0-5aee6eae1b65
# 92764                 True  56592e71-b345-4e2c-877c-78213e678297
# 101517                True  36614f91-9336-453c-b2f7-0b1d58465c8e
# 109635                True  0cbda608-e393-4826-853c-1a8fa15dca3a
#
#        cases.submitter_id
# 91075    10000364-2397900
# 92304    10000364-2022035
# 92764    10000364-1058096
# 101517   10000364-1437263
# 109635   10000364-5461045
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Get the imaging files for the identified studies or cases.
# ---
# Now that we have a list of relevant imaging studies t, we can use the study_uid, which is a unique identifier for imaging studies, to collect the associated files.

# %%
## Make a list of study_uids and case_ids

## read in previously saved DataFrame if restarting notebook:
# pd.read_csv(filename, sep='\t', dtype=str)

cids = list(set(ps['case_ids']))
display(len(cids))

sids = list(set(ps['study_uid']))
display(len(sids))
ps.head(5)
list(ps)
# Out:
# 22
# 22
# ['type',
#  'id',
#  'project_id',
#  'submitter_id',
#  'age_at_imaging',
#  'age_at_imaging_gt89',
#  'body_part_examined',
#  'case_ids',
#  'days_from_study_to_neg_covid_test',
#  'days_from_study_to_pos_covid_test',
#  'days_to_study',
#  'loinc_code',
#  'loinc_contrast',
#  'loinc_long_common_name',
#  'loinc_method',
#  'loinc_system',
#  'study_description',
#  'study_location',
#  'study_modality',
#  'study_uid',
#  'study_year',
#  'study_year_shifted',
#  'cases.id',
#  'cases.submitter_id']

# %%
## This query retrieves ALL imaging_study records, we will next filter these results based on the COVID test data
data = query.raw_data_download(
    data_type="imaging_study",
    fields=[
        "study_uid",
        "case_ids",
        "object_id",
        "project_id",
        "days_to_study",
        "study_modality"
    ],
    sort_fields=[{"case_ids": "asc"}],
    accessibility="accessible"
)

# %%
# convert the query data to a DataFrame and remove any records that lack a study_uid or object_id
studies = pd.DataFrame(data)
studies = studies.loc[(~studies['object_id'].isna())&(~studies['study_uid'].isna())]
display(len(studies))
studies.head(5)
# Out:
# 137707
#    days_to_study study_modality                           case_ids  \
# 0            3.0           [CR]                    [419639-000340]
# 1           -7.0           [CR]                 [10000364-5525032]
# 2           50.0           [CR]  [10003752-BeDxoSuS6EGO2d3VaDdxvA]
# 3            5.0           [DX]                    [302028-006645]
# 4         -190.0           [CT]                  [10000364-796304]
#
#                                            study_uid project_id  \
# 0  1.2.826.0.1.3680043.10.474.419639.796349784997...    Open-R1
# 1  2.16.840.1.114274.1818.51687401151122173581269...    Open-A1
# 2  2.16.840.1.114274.1818.56868609356553584055729...    Open-A1
# 3          1.2.826.0.1.3680043.10.474.302028.2753542    Open-R1
# 4  2.16.840.1.114274.1818.48559242508824544311053...    Open-A1
#
#                                            object_id
# 0     [dg.MD1R/7e6dfa45-dd3a-4275-9522-016a671f3152]
# 1  [dg.MD1R/bc1a4a11-1d97-4cf3-bf9c-4a9c964d588a,...
# 2     [dg.MD1R/fe5df236-4567-492f-a9b8-fdf110494b6e]
# 3     [dg.MD1R/5e408de5-17b1-4a02-9ec3-109a827f1160]
# 4  [dg.MD1R/24504ade-a4a2-44ca-87e6-77c4ba115452,...

# %%
# Now filter the imaging studies 
covid_studies = studies.loc[(studies['study_uid'].isin(sids))]
print('\n unique imaging studies:{}'.format(len(covid_studies)))
covid_studies.head(5)
list(covid_studies)
# Out:
#  unique imaging studies:22
# ['days_to_study',
#  'study_modality',
#  'case_ids',
#  'study_uid',
#  'project_id',
#  'object_id']

# %%
# save our result to a csv
filename = "MRI.tsv"
covid_studies.to_csv(filename, sep='\t', index=False)
covid_studies.head(22)
object_ids = list(set([a for b in covid_studies.object_id.tolist() for a in b]))
#object_ids = list(set([a for b in covid_studies.object_id.tolist() for a in b]))
len(object_ids)
# Out:
# 134

# %% [markdown]
# ## Now that we have a list of file object_ids for the desired imaging studies, we can use the Gen3 SDK "drs-pull" commands to access the files themselves.
# ---
# First, we'll create a manifest.json file using a [simple script](https://github.com/cgmeyer/gen3sdk-python/blob/389e3945482439ace6e4536e6d0e35c6e48de9c9/expansion/expansion.py#L2575). Then we'll use the `gen3 drs-pull manifest` command to download the files.
#
# See the detailed documentation to learn more about the Gen3 SDK drs-pull command: https://github.com/uc-cdis/gen3sdk-python/blob/master/docs/howto/drsDownloading.md

# %%
# Save the manifest of file object_ids to a JSON file
mani_name = 'MRImanifest20230704.json'
exp.write_manifest(guids=object_ids, filename=mani_name)
# Out:
# 	Done (134/134).
# 	Manifest written to file: MRImanifest20230704.json
# 'MRImanifest20230704.json'

# %%
# To download all files in the manifest, use the "gen3 drs-pull manifest" command
download_dir = "{}/images".format(demo_dir)

if not os.path.exists(download_dir):
    os.makedirs(download_dir)
    
cmd = "gen3 --auth {} --endpoint data.midrc.org drs-pull manifest {} {}".format(cred, mani_name, download_dir)
print(cmd)


## Option 1: To monitor the progress in real-time, you can copy the command generated below
## and run in your terminal instead of from this Jupyter Notebook.
# Out:
# gen3 --auth /Users/heatherwhitney/Documents/MRIbootcamp/credentials.json --endpoint data.midrc.org drs-pull manifest MRImanifest20230704.json /Users/heatherwhitney/Documents/MRIbootcamp/images

# %%
## Option 2: Run the manifest download command. 
## Note that this will take some time if the manifest is very large. 
subprocess.run(cmd, shell=True, capture_output=True)
# Out:
# CompletedProcess(args='gen3 --auth /Users/heatherwhitney/Documents/MRIbootcamp/credentials.json --endpoint data.midrc.org drs-pull manifest MRImanifest20230704.json /Users/heatherwhitney/Documents/MRIbootcamp/images', returncode=0, stdout=b'', stderr=b'\rResolving objects:   0%|          | 0/134 [00:00<?, ?it/s]\rResolving objects:   1%|          | 1/134 [00:00<00:39,  3.34it/s]\rResolving objects:   1%|\xe2\x96\x8f         | 2/134 [00:00<00:36,  3.58it/s]\rResolving objects:   2%|\xe2\x96\x8f         | 3/134 [00:00<00:34,  3.79it/s]\rResolving objects:   3%|\xe2\x96\x8e         | 4/134 [00:01<00:35,  3.63it/s]\rResolving objects:   4%|\xe2\x96\x8e         | 5/134 [00:01<00:34,  3.69it/s]\rResolving objects:   4%|\xe2\x96\x8d         | 6/134 [00:01<00:33,  3.83it/s]\rResolving objects:   5%|\xe2\x96\x8c         | 7/134 [00:01<00:32,  3.87it/s]\rResolving objects:   6%|\xe2\x96\x8c         | 8/134 [00:02<00:36,  3.46it/s]\rResolving objects:   7%|\xe2\x96\x8b         | 9/134 [00:02<00:34,  3.62it/s]\rResolving objects:   7%|\xe2\x96\x8b         | 10/134 [00:02<00:32,  3.80it/s]\rResolving objects:   8%|\xe2\x96\x8a         | 11/134 [00:02<00:31,  3.86it/s]\rResolving objects:   9%|\xe2\x96\x89         | 12/134 [00:03<00:30,  3.95it/s]\rResolving objects:  10%|\xe2\x96\x89         | 13/134 [00:03<00:29,  4.08it/s]\rResolving objects:  10%|\xe2\x96\x88         | 14/134 [00:03<00:29,  4.12it/s]\rResolving objects:  11%|\xe2\x96\x88         | 15/134 [00:03<00:29,  4.06it/s]\rResolving objects:  12%|\xe2\x96\x88\xe2\x96\x8f        | 16/134 [00:04<00:28,  4.10it/s]\rResolving objects:  13%|\xe2\x96\x88\xe2\x96\x8e        | 17/134 [00:04<00:29,  3.99it/s]\rResolving objects:  13%|\xe2\x96\x88\xe2\x96\x8e        | 18/134 [00:04<00:28,  4.10it/s]\rResolving objects:  14%|\xe2\x96\x88\xe2\x96\x8d        | 19/134 [00:04<00:27,  4.16it/s]\rResolving objects:  15%|\xe2\x96\x88\xe2\x96\x8d        | 20/134 [00:05<00:27,  4.15it/s]\rResolving objects:  16%|\xe2\x96\x88\xe2\x96\x8c        | 21/134 [00:05<00:27,  4.12it/s]\rResolving objects:  16%|\xe2\x96\x88\xe2\x96\x8b        | 22/134 [00:05<00:27,  4.07it/s]\rResolving objects:  17%|\xe2\x96\x88\xe2\x96\x8b        | 23/134 [00:05<00:27,  4.01it/s]\rResolving objects:  18%|\xe2\x96\x88\xe2\x96\x8a        | 24/134 [00:06<00:26,  4.16it/s]\rResolving objects:  19%|\xe2\x96\x88\xe2\x96\x8a        | 25/134 [00:06<00:26,  4.12it/s]\rResolving objects:  19%|\xe2\x96\x88\xe2\x96\x89        | 26/134 [00:06<00:25,  4.18it/s]\rResolving objects:  20%|\xe2\x96\x88\xe2\x96\x88        | 27/134 [00:06<00:25,  4.12it/s]\rResolving objects:  21%|\xe2\x96\x88\xe2\x96\x88        | 28/134 [00:07<00:25,  4.19it/s]\rResolving objects:  22%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x8f       | 29/134 [00:07<00:24,  4.25it/s]\rResolving objects:  22%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x8f       | 30/134 [00:07<00:25,  4.15it/s]\rResolving objects:  23%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x8e       | 31/134 [00:07<00:24,  4.12it/s]\rResolving objects:  24%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x8d       | 32/134 [00:08<00:25,  4.06it/s]\rResolving objects:  25%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x8d       | 33/134 [00:08<00:25,  4.03it/s]\rResolving objects:  25%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x8c       | 34/134 [00:08<00:24,  4.07it/s]\rResolving objects:  26%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x8c       | 35/134 [00:08<00:23,  4.17it/s]\rResolving objects:  27%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x8b       | 36/134 [00:08<00:23,  4.13it/s]\rResolving objects:  28%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x8a       | 37/134 [00:09<00:23,  4.08it/s]\rResolving objects:  28%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x8a       | 38/134 [00:09<00:23,  4.07it/s]\rResolving objects:  29%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x89       | 39/134 [00:09<00:23,  4.09it/s]\rResolving objects:  30%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x89       | 40/134 [00:09<00:22,  4.09it/s]\rResolving objects:  31%|\xe2\x96\x88\xe2\x96\x88\xe2\x96\x88       | 41/134 [00:10<00:22,  4.07it/ ...
